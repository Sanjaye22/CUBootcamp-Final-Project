# %%
import pandas as pd

# %%
file_one = "C:/Users/Keke/git/CUBootcamp-Final-Project/Datasets/drugsComTest.csv"
file_two = "C:/Users/Keke/git/CUBootcamp-Final-Project/Datasets/drugsComTrain.csv"

# %%
testdata = pd.read_csv(file_one)
traindata= pd.read_csv(file_two)

# %%
testdata.head()
# Out:
#    uniqueID drugName                                          condition  \
# 0    103785  ZzzQuil                                           Insomnia
# 1     51804    Zyvox                                         Bacteremia
# 2     51790    Zyvox                       Skin and Structure Infection
# 3     51784    Zyvox                                Bacterial Infection
# 4     51797    Zyvox  Methicillin-Resistant Staphylococcus Aureus In...
#
#                                               review  rating       date  \
# 0              "Gave me rapid heart beats !!!!!!!!!"       1  26-May-17
# 1                                "It cured my MRSA."       9   8-Oct-08
# 2  "I have been on zyvox for 6 weeks now and have...       7   3-Jul-15
# 3  "It didn't work as fast as I thought it would....       6  17-Apr-16
# 4  "I have had 5 major abdominal sugeries in the ...       9   7-Dec-09
#
#    usefulCount
# 0            1
# 1           20
# 2            6
# 3            1
# 4           22

# %%
traindata.head()
# Out:
#    uniqueID                  drugName                     condition  \
# 0    206461                 Valsartan  Left Ventricular Dysfunction
# 1     95260                Guanfacine                          ADHD
# 2     92703                    Lybrel                 Birth Control
# 3    138000                Ortho Evra                 Birth Control
# 4     35696  Buprenorphine / naloxone             Opiate Dependence
#
#                                               review  rating       date  \
# 0  "It has no side effect, I take it in combinati...       9  20-May-12
# 1  "My son is halfway through his fourth week of ...       8  27-Apr-10
# 2  "I used to take another oral contraceptive, wh...       5  14-Dec-09
# 3  "This is my first time using any form of birth...       8   3-Nov-15
# 4  "Suboxone has completely turned my life around...       9  27-Nov-16
#
#    usefulCount
# 0           27
# 1          192
# 2           17
# 3           10
# 4           37
